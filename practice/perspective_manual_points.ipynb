# %% [markdown]
# <a href="https://colab.research.google.com/github/andreidm92/computer_vision_tasks/blob/main/practice/perspective_manual_points.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📚 Тема: Перспективное преобразование изображения (ручной выбор точек)

# %% [markdown]
# ## 📋 Описание
# В этом ноутбуке мы вручную выберем координаты 4 углов объекта на изображении для выполнения перспективного преобразования.

# %% [markdown]
# ## 🛠 План работы
# 1. Загрузить и показать изображение
# 2. Визуально определить 4 угла
# 3. Ввести координаты вручную
# 4. Выполнить перспективное преобразование

# %% [markdown]
# ## 📚 Теория
# Перспективное преобразование позволяет "выпрямить" объекты на изображении, снятые под углом. Используется матрица 3×3, построенная по 4 парам точек.

# %%
# Шаг 1: Импорты
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
# Шаг 2: Загрузка изображения
img = cv2.imread('Paper.jpg')  # Заменить на путь к своему изображению
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Показ изображения
plt.figure(figsize=(8,6))
plt.imshow(img)
plt.title("Определи 4 угла объекта")
plt.axis('on')
plt.show()

# %%
# Шаг 3: Ввод координат вручную
# Пример координат (замени на свои после просмотра изображения)
points = np.float32([
    [80, 80],   # Левый верхний угол
    [300, 25],   # Правый верхний угол
    [235, 335],   # Левый нижний угол
    [510, 230]    # Правый нижний угол
])

# Координаты после трансформации (размер нового изображения)
pts2 = np.float32([
    [0, 0],
    [300, 0],
    [0, 400],
    [300, 400]
])

# %%
# Шаг 4: Перспективное преобразование
M = cv2.getPerspectiveTransform(points, pts2)
warped = cv2.warpPerspective(img, M, (300, 400))

# Показ результата
plt.figure(figsize=(8,6))
plt.imshow(warped)
plt.title("Выпрямленное изображение")
plt.axis('off')
plt.show()

# %% [markdown]
# ## ✅ Выводы
# - Научился вручную выбирать координаты углов на изображении.
# - Провёл перспективное преобразование через OpenCV.
# - Получил выпрямленное изображение.

# %% [markdown]
# ## ❓ Контрольные вопросы
# 1. Почему нужны именно 4 пары точек для перспективного преобразования?
# 2. Что будет, если точки задать в неправильном порядке?
# 3. Почему результат иногда может быть искажённым?

# %% [markdown]
# ## 📂 Что сделать
# - Сохранить этот ноутбук в папку `practice/` под именем `perspective_manual_points.ipynb`
# - Залить результат на GitHub
# - Отметить ✅ в своём трекере
